# %% [markdown]
# <a href="https://colab.research.google.com/github/kakhramonov99/Consequences-of-Sleep-Duration/blob/main/Sleep_health_and_lifestyle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Sleep_health_and_lifestyle_dataset

# %%
# Import libriries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# upload dataset
df = pd.read_csv('Sleep_health_and_lifestyle_dataset.csv')
df.head(10)
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
# 5          6   Male   28     Software Engineer             5.9
# 6          7   Male   29               Teacher             6.3
# 7          8   Male   29                Doctor             7.8
# 8          9   Male   29                Doctor             7.8
# 9         10   Male   29                Doctor             7.8
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
# 5                 4                       30             8        Obese
# 6                 6                       40             7        Obese
# 7                 7                       75             6       Normal
# 8                 7                       75             6       Normal
# 9                 7                       75             6       Normal
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# 1         125/80          75        10000            NaN
# 2         125/80          75        10000            NaN
# 3         140/90          85         3000    Sleep Apnea
# 4         140/90          85         3000    Sleep Apnea
# 5         140/90          85         3000       Insomnia
# 6         140/90          82         3500       Insomnia
# 7         120/80          70         8000            NaN
# 8         120/80          70         8000            NaN
# 9         120/80          70         8000            NaN

# %%
# The number of rows and columns in dataset
print(f'Number of rows {df.shape[0]} and columns {df.shape[1]}')
# Out:
# Number of rows 374 and columns 13

# %%
# Print dataset info
print("\nThe info of Sleep health and lifestyle dataset:")
print(df.info())

# Print statistical summary
print("\nThe describe of Sleep health and lifestyle dataset:")
print(df.describe())
# Out:
# The info of Sleep health and lifestyle dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB
# None
#
# The describe of Sleep health and lifestyle dataset:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# 25%                  45.000000      4.000000   68.000000   5600.000000
# 50%                  60.000000      5.000000   70.000000   7000.000000
# 75%                  75.000000      7.000000   72.000000   8000.000000
# max                  90.000000      8.000000   86.000000  10000.000000

# %%
df.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# 25%                  45.000000      4.000000   68.000000   5600.000000
# 50%                  60.000000      5.000000   70.000000   7000.000000
# 75%                  75.000000      7.000000   72.000000   8000.000000
# max                  90.000000      8.000000   86.000000  10000.000000

# %%
# 1. Extract Numerical Columns from whole dataset, because, we have to determine which column is correlated
num_cols = ["Age", "Sleep Duration", "Quality of Sleep", "Physical Activity Level", "Stress Level", "Heart Rate", "Daily Steps"]
df_num = df[num_cols]

# %%
# 1) Sample Mean
print("Sample Mean:\n", df_num.mean(), "\n")

# 2) Median
print("Median:\n", df_num.median(), "\n")

# 3) Max
print("Max:\n", df_num.max(), "\n")

# 4) Max
print("Min:\n", df_num.min(), "\n")
# Out:
# Sample Mean:
#  Age                          42.184492
# Sleep Duration                7.132086
# Quality of Sleep              7.312834
# Physical Activity Level      59.171123
# Stress Level                  5.385027
# Heart Rate                   70.165775
# Daily Steps                6816.844920
# dtype: float64
#
# Median:
#  Age                          43.0
# Sleep Duration                7.2
# Quality of Sleep              7.0
# Physical Activity Level      60.0
# Stress Level                  5.0
# Heart Rate                   70.0
# Daily Steps                7000.0
# dtype: float64
#
# Max:
#  Age                           59.0
# Sleep Duration                 8.5
# Quality of Sleep               9.0
# Physical Activity Level       90.0
# Stress Level                   8.0
# Heart Rate                    86.0
# Daily Steps                10000.0
# dtype: float64
#
# Min:
#  Age                          27.0
# Sleep Duration                5.8
# Quality of Sleep              4.0
# Physical Activity Level      30.0
# Stress Level                  3.0
# Heart Rate                   65.0
# Daily Steps                3000.0
# dtype: float64

# %%
# for Sleep Duration
sleep_dur_list = df['Sleep Duration'].values.tolist()
sleep_dur_array = df['Sleep Duration'].values
sleep_dur_frame = df['Sleep Duration']

# %% [markdown]
# # Cumilative Distribution Function (CDF)

# %%
# Calculation CDF for Sleep Duration
def calculate_cdf(sleep_dur_list):
  sorted_data = sorted(sleep_dur_list)
  return sorted_data, np.arange(0,1,1/len(sorted_data))

x, y = calculate_cdf(sleep_dur_list)
plt.plot(x,y, label="CDF", color='red')
plt.xlabel('x')
plt.ylabel('F^(x)')
plt.legend()

# %%
# Inverse CDF for Sleep Duration
def quartiles(sleep_dur_list):
  Q0 = sleep_dur_list[0] # 0%
  Q1 = sleep_dur_list[int(len(sleep_dur_list)*0.25)] # 25%
  Q2 = sleep_dur_list[int(len(sleep_dur_list)*0.5)] # 50%
  Q3 = sleep_dur_list[int(len(sleep_dur_list)*0.75)] # 75%
  Q4 = sleep_dur_list[int(len(sleep_dur_list)*1.0)-1] # 100%

  return Q0,Q1,Q2, Q3, Q4
Q = quartiles(x)
Q
# Out:
# (5.8, 6.4, 7.2, 7.8, 8.5)

# %%
# Inverse CDF Sleep Duration
plt.plot(y,x, label = "Inverse CDF")
plt.scatter([0,0.25,0.5,0.75,1], Q, color = 'r') # 0.5

#plot.plot()
plt.xlabel('Probability')
plt.ylabel('F^-1(p)')
plt.legend()

# %%
# IQR
IQR = Q[3]-Q[1]
IQR
# Out:
# 1.3999999999999995

# %%
# Outlier detection
less_min = df[df['Sleep Duration']<Q[1]-1.5*IQR] # less than min
more_max = df[df['Sleep Duration']>Q[1]+1.5*IQR] # less than min
print(less_min.size)
print(more_max.size)
# Out:
# 0
# 0

# %%
#PMF for Sleep Duration

def calculate_pmf(sleep_dur_list):
  unique_values, counts = np.unique(sleep_dur_list, return_counts=True)
  pmf = counts/len(sleep_dur_list)
  return unique_values, pmf

# Example usage (assuming 'df' is your DataFrame)
unique_x, pmf_y = calculate_pmf(df['Sleep Duration'])

#Plotting the PMF
plt.stem(unique_x, pmf_y, label='PMF')
plt.xlabel('x')
plt.ylabel('P(X=x)')
plt.legend()

# %%
# mode
mode_idx = np.argmax(pmf_y)
unique_x[mode_idx]
# Out:
# np.float64(7.2)

# %%
# Calculating Variance for Sleep Duration
def variance(array):
  # mean
  mean = np.mean(array)
  #farqlar kvadrati
  sq_diff = (array - mean)**2

  #variance
  return np.sum(sq_diff)/len(array)

variance = variance(df['Sleep Duration'].values)
variance
# Out:
# np.float64(0.6313769338557008)

# %%
# Bivariate analysis with Sleep Duration and Quality of Sleep

# for Sleep Duration
sleep_dur_list = df['Sleep Duration'].values.tolist()
sleep_dur_array = df['Sleep Duration'].values
sleep_dur_frame = df['Sleep Duration']

# for Quality of Sleep
quality_sleep_list = df['Quality of Sleep'].values.tolist()
quality_sleep_array = df['Quality of Sleep'].values
quality_sleep_frame = df['Quality of Sleep']

# %%
# Calculating coveriance for Sleep Duration and Quality of Sleep
def calculate_covariance(sleep_dur_list,quality_sleep_list):
  if len(sleep_dur_list) != len(quality_sleep_list):
    raise ValueError("List x1 va x2 should be equal each other")

  n = len(sleep_dur_list)
  mean_sleep_dur = sum(sleep_dur_list)/n
  mean_quality_sleep = sum(quality_sleep_list)/n

  covariance = sum((sleep_dur_list[i]-mean_sleep_dur)*(quality_sleep_list[i]-mean_quality_sleep) for i in range(n))/n
  return covariance

calculate_covariance(sleep_dur_list, quality_sleep_list)
# Out:
# 0.8388930195315851

# %%
# Normal distribution for Sleep Duration

def calculate_pdf_vectorized(data):
  mu = np.mean(data)
  sigma = np.std(data, ddof=1)
  coeff = 1/(sigma*np.sqrt(2*np.pi))

  # Compute the exponent part for all data points in one go
  exponent = np.exp(-((data-mu)**2)/(2*sigma**2))

  return coeff*exponent

# Calculate for PDF for all data in sepal length array

pdf_values = calculate_pdf_vectorized(sleep_dur_array)
print("PDF values for the sepal length data:")
print(pdf_values)
plt.scatter(sleep_dur_array, pdf_values)
# Out:
# PDF values for the sepal length data:
# [0.21617884 0.25245595 0.25245595 0.15117777 0.15117777 0.15117777
#  0.29020032 0.35250528 0.35250528 0.35250528 0.21617884 0.35250528
#  0.21617884 0.18221353 0.18221353 0.18221353 0.36571439 0.18221353
#  0.36571439 0.4217791  0.38864708 0.38864708 0.38864708 0.38864708
#  0.35250528 0.31471374 0.35250528 0.31471374 0.31471374 0.31471374
#  0.32835984 0.32835984 0.31471374 0.21617884 0.38864708 0.21617884
#  0.21617884 0.4217791  0.4217791  0.4217791  0.38864708 0.38864708
#  0.38864708 0.35250528 0.38864708 0.35250528 0.38864708 0.35250528
#  0.38864708 0.38864708 0.450562   0.450562   0.18221353 0.4217791
#  0.18221353 0.18221353 0.38864708 0.18221353 0.18221353 0.38864708
#  0.18221353 0.18221353 0.25245595 0.25245595 0.25245595 0.25245595
#  0.49957679 0.18221353 0.25245595 0.25245595 0.21617884 0.21617884
#  0.21617884 0.21617884 0.18221353 0.18221353 0.18221353 0.18221353
#  0.18221353 0.18221353 0.12346251 0.12346251 0.43265891 0.43265891
#  0.450562   0.49957679 0.49957679 0.49957679 0.49035788 0.49035788
#  0.49035788 0.49035788 0.450562   0.47376604 0.49957679 0.50099248
#  0.49957679 0.50099248 0.50099248 0.50099248 0.49957679 0.49957679
#  0.49957679 0.40093495 0.49957679 0.40093495 0.21617884 0.35250528
#  0.35250528 0.47376604 0.49957679 0.47376604 0.49957679 0.47376604
#  0.49957679 0.49957679 0.49957679 0.49957679 0.49957679 0.49957679
#  0.49957679 0.49957679 0.49957679 0.49957679 0.49957679 0.450562
#  0.49035788 0.50099248 0.49035788 0.49035788 0.50099248 0.49035788
#  0.49035788 0.50099248 0.49035788 0.49035788 0.50099248 0.50099248
#  0.50099248 0.50099248 0.50099248 0.50099248 0.50099248 0.50099248
#  0.50099248 0.47376604 0.49957679 0.36571439 0.48051694 0.27657037
#  0.27657037 0.49957679 0.49957679 0.49957679 0.49957679 0.49957679
#  0.49957679 0.49957679 0.49957679 0.49957679 0.49957679 0.49957679
#  0.49957679 0.31471374 0.31471374 0.4217791  0.49035788 0.50099248
#  0.50099248 0.38864708 0.38864708 0.38864708 0.38864708 0.38864708
#  0.4217791  0.4217791  0.4217791  0.36571439 0.35250528 0.35250528
#  0.35250528 0.35250528 0.35250528 0.35250528 0.4595759  0.4595759
#  0.43265891 0.29020032 0.43265891 0.36571439 0.43265891 0.32835984
#  0.36571439 0.36571439 0.36571439 0.36571439 0.36571439 0.36571439
#  0.36571439 0.36571439 0.36571439 0.35250528 0.35250528 0.48051694
#  0.4217791  0.38864708 0.38864708 0.38864708 0.38864708 0.35250528
#  0.38864708 0.35250528 0.35250528 0.35250528 0.35250528 0.35250528
#  0.35250528 0.35250528 0.35250528 0.36571439 0.40093495 0.32835984
#  0.29020032 0.32835984 0.40093495 0.29020032 0.40093495 0.29020032
#  0.40093495 0.29020032 0.40093495 0.29020032 0.40093495 0.29020032
#  0.40093495 0.29020032 0.32835984 0.36571439 0.29020032 0.32835984
#  0.36571439 0.29020032 0.32835984 0.36571439 0.29020032 0.36571439
#  0.29020032 0.4595759  0.32835984 0.36571439 0.4595759  0.4595759
#  0.36571439 0.36571439 0.36571439 0.36571439 0.40093495 0.40093495
#  0.40093495 0.40093495 0.40093495 0.40093495 0.40093495 0.48051694
#  0.49035788 0.15117777 0.49035788 0.25245595 0.18221353 0.21617884
#  0.21617884 0.21617884 0.21617884 0.25245595 0.25245595 0.25245595
#  0.23924092 0.23924092 0.21617884 0.17073189 0.18221353 0.21617884
#  0.18221353 0.18221353 0.18221353 0.18221353 0.18221353 0.18221353
#  0.18221353 0.21617884 0.18221353 0.21617884 0.21617884 0.18221353
#  0.21617884 0.18221353 0.21617884 0.21617884 0.11438085 0.11438085
#  0.11438085 0.11438085 0.50099248 0.18221353 0.21617884 0.21617884
#  0.36571439 0.36571439 0.40093495 0.40093495 0.40093495 0.40093495
#  0.14085234 0.14085234 0.14085234 0.17073189 0.11438085 0.11438085
#  0.14085234 0.14085234 0.11438085 0.14085234 0.14085234 0.11438085
#  0.17073189 0.11438085 0.17073189 0.11438085 0.17073189 0.11438085
#  0.11438085 0.14085234 0.14085234 0.14085234 0.14085234 0.14085234
#  0.14085234 0.14085234 0.11438085 0.23924092 0.23924092 0.20370661
#  0.20370661 0.23924092 0.20370661 0.20370661 0.20370661 0.20370661
#  0.20370661 0.23924092 0.23924092 0.23924092 0.27657037 0.27657037
#  0.27657037 0.27657037 0.27657037 0.27657037 0.27657037 0.23924092
#  0.20370661 0.20370661 0.20370661 0.20370661 0.27657037 0.27657037
#  0.23924092 0.27657037 0.23924092 0.23924092 0.27657037 0.23924092
#  0.23924092 0.23924092]

# %%
# Calculating correlation for Sleep Duration and Quality of Sleep

def calculate_correlation(X1, X2):
  if len(X1)!= len(X2):
    raise ValueError("List x1 va x2 bir biriga teng bo'lishi kerak")

  n = len(X1)
  mean_X1 = sum(X1)/n
  mean_X2 = sum(X2)/n

  #calculate covariance

  cov = sum((X1[i]-mean_X1)*(X2[i]-mean_X2) for i in range(n))/n

  #calculate  the SD of X1 and X2
  std_X1 = (sum((xi-mean_X1)**2 for xi in X1)/n)**0.5
  std_X2 = (sum((xi-mean_X2)**2 for xi in X2)/n)**0.5

  #Calculate correlation coofeitsient
  if std_X1 == 0 or std_X2 == 0:
    raise ValueError("SD cannot be zero for correlaation calculation")

  correlation = cov/(std_X1*std_X2)

  return correlation

calculate_correlation(sleep_dur_list, quality_sleep_list)
# Out:
# 0.8832130004106182

# %%
df[['Sleep Duration', 'Quality of Sleep', 'Stress Level']].corr()
# Out:
#                   Sleep Duration  Quality of Sleep  Stress Level
# Sleep Duration          1.000000          0.883213     -0.811023
# Quality of Sleep        0.883213          1.000000     -0.898752
# Stress Level           -0.811023         -0.898752      1.000000

# %%
# The relationship between Sleep Duration and Quality of Sleep
plt.scatter(df["Sleep Duration"], df["Quality of Sleep"], alpha=0.6)
plt.xlabel("Sleep Duration (hours)")
plt.ylabel("Quality of Sleep (1-10)")
plt.title("Sleep Duration vs Quality of Sleep")

# Trend line
m, b = np.polyfit(df["Sleep Duration"], df["Quality of Sleep"], 1)
plt.plot(df["Sleep Duration"], m*df["Sleep Duration"]+b, color="r")

# %%
# The relationship between Sleep Duration and Stress Level

plt.scatter(df["Sleep Duration"], df["Stress Level"], alpha=0.6)
plt.xlabel("Sleep Duration (hours)")
plt.ylabel("Stress Level (1-10)")
plt.title("Sleep Duration vs Stress Level")

# Trend line
m, b = np.polyfit(df["Sleep Duration"], df["Stress Level"], 1)
plt.plot(df["Sleep Duration"], m*df["Sleep Duration"]+b, color="red")

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111, projection="3d")

ax.scatter(df["Sleep Duration"], df["Quality of Sleep"], df["Stress Level"], c=df["Stress Level"], cmap="viridis")

ax.set_xlabel("Sleep Duration (hours)")
ax.set_ylabel("Quality of Sleep (1-10)")
ax.set_zlabel("Stress Level (1-10)")
plt.title("3D Relationship: Sleep Duration vs Quality of Sleep vs Stress Level")
# Out:
# Text(0.5, 0.92, '3D Relationship: Sleep Duration vs Quality of Sleep vs Stress Level')

# %%
df.loc[:, ['Sleep Duration', 'Quality of Sleep', 'Stress Level']]
# Out:
#      Sleep Duration  Quality of Sleep  Stress Level
# 0               6.1                 6             6
# 1               6.2                 6             8
# 2               6.2                 6             8
# 3               5.9                 4             8
# 4               5.9                 4             8
# ..              ...               ...           ...
# 369             8.1                 9             3
# 370             8.0                 9             3
# 371             8.1                 9             3
# 372             8.1                 9             3
# 373             8.1                 9             3
#
# [374 rows x 3 columns]

# %%
# Only Numerical Columns
numeric_cols = df.select_dtypes(include=np.number).columns

# Correlation Matrix
corr_matrix = df[numeric_cols].corr()

print("For each Numerical columns Correlation matrix")
print(corr_matrix)
# Out:
# For each Numerical columns Correlation matrix
#                          Person ID       Age  Sleep Duration  \
# Person ID                 1.000000  0.990516        0.296305
# Age                       0.990516  1.000000        0.344709
# Sleep Duration            0.296305  0.344709        1.000000
# Quality of Sleep          0.431612  0.473734        0.883213
# Physical Activity Level   0.149882  0.178993        0.212360
# Stress Level             -0.394287 -0.422344       -0.811023
# Heart Rate               -0.225467 -0.225606       -0.516455
# Daily Steps               0.043844  0.057973       -0.039533
#
#                          Quality of Sleep  Physical Activity Level  \
# Person ID                        0.431612                 0.149882
# Age                              0.473734                 0.178993
# Sleep Duration                   0.883213                 0.212360
# Quality of Sleep                 1.000000                 0.192896
# Physical Activity Level          0.192896                 1.000000
# Stress Level                    -0.898752                -0.034134
# Heart Rate                      -0.659865                 0.136971
# Daily Steps                      0.016791                 0.772723
#
#                          Stress Level  Heart Rate  Daily Steps
# Person ID                   -0.394287   -0.225467     0.043844
# Age                         -0.422344   -0.225606     0.057973
# Sleep Duration              -0.811023   -0.516455    -0.039533
# Quality of Sleep            -0.898752   -0.659865     0.016791
# Physical Activity Level     -0.034134    0.136971     0.772723
# Stress Level                 1.000000    0.670026     0.186829
# Heart Rate                   0.670026    1.000000    -0.030309
# Daily Steps                  0.186829   -0.030309     1.000000

# %%
# The relationship between Physical Activity Level and Daily Steps

plt.scatter(df["Physical Activity Level"], df["Daily Steps"], alpha=0.6)
plt.xlabel("Physical Activity Level")
plt.ylabel("Daily Steps")
plt.title("Physical Activity Level vs Daily Steps")

# Trend line
m, b = np.polyfit(df["Physical Activity Level"], df["Daily Steps"], 1)
plt.plot(df["Physical Activity Level"], m*df["Physical Activity Level"]+b, color="red")

# %%
occup_counts = df["Occupation"].value_counts()

plt.figure(figsize=(12,6))
occup_counts.plot(kind="bar", color="blue", edgecolor="black")
plt.title("Distribution of Occupation")
plt.xlabel("Occupation")
plt.ylabel("Number of People")
plt.xticks(rotation=45)
plt.show()

# %%
occup_count= df['Occupation'].value_counts()
print('Number of people in each',occup_count)
# Out:
# Number of people in each Occupation
# Nurse                   73
# Doctor                  71
# Engineer                63
# Lawyer                  47
# Teacher                 40
# Accountant              37
# Salesperson             32
# Scientist                4
# Software Engineer        4
# Sales Representative     2
# Manager                  1
# Name: count, dtype: int64

# %%
occup_counts = df["Age"].value_counts()

plt.figure(figsize=(12,6))
occup_counts.plot(kind="bar", color="blue", edgecolor="black")
plt.title("Age Distribution")
plt.xlabel("Ages")
plt.ylabel("Number of People")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,6))

# For each gender draw individual line
for gender in df["Gender"].unique():
    subset = df[df["Gender"] == gender]
    plt.plot(subset["Age"], subset["Sleep Duration"], marker='o', linestyle='--', label=gender)

plt.xlabel("Age")
plt.ylabel("Sleep Duration")
plt.title("Sleep Duration Distribution by Gender and Age")
plt.legend(title="Gender")
plt.show()
